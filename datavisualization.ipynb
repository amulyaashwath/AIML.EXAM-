# %% [markdown]
# <a href="https://colab.research.google.com/github/amulyaashwath/AIML.EXAM-/blob/main/datavisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the Datasets

# %%
data=pd.read_csv('Salary_Data.csv')
x=data.iloc[:,:-1].values 
y=data.iloc[:,:-1].values

# %% [markdown]
# Plotting graphs

# %%
#scattergraph
plt.scatter(x,y)
plt.show()

# %%
#linegraph
plt.plot(x,y)
plt.show()

# %%
#histogram
plt.hist(x)
plt.show()

# %%
#bargraph
data.plot(kind='bar')
plt.show()
